# %%
import numpy as np

def numerical_derivative(f,x):
    delta_x=1e-4
    grad=np.zeros_like(x)
    print('debug 1. initial input variable = ', x)
    print('debug 2. initial grad = ', grad)
    # 구분선 출력 코드
    for i in range (40):
        print('=', end='')
    print()

    it=np.nditer(x,flags=['multi_index'], op_flags=['readwrite'])

    while not it.finished:
        idx=it.multi_index
        print('debug 3. idx = ', idx, ', x[idx] = ', x[idx])

        tmp_val=x[idx]
        x[idx]=float(tmp_val)+delta_x
        fx1=f(x) #f(x+delta_x)

        x[idx]=float(tmp_val)-delta_x
        fx2=f(x) #f(x-delta_x)
        grad[idx]=(fx1-fx2)/(2*delta_x)
        print('debug 4. grad[idx] =', grad[idx])
        print('debug 5. grad =', grad)
        # 구분선 출력 코드
        for i in range (40):
            print('=', end='')
        print()        

        x[idx]=tmp_val
        it.iternext()
    
    
    return grad

# 입력 변수가 1개인 함수 f(x)=x**2
def func1(w):
    x=w
    

    return x**2

# lambda 함수 정의
f=lambda w: func1(w)

w=np.array([3.0])

# x=3.0에서의 편미분 값
ret=numerical_derivative(f,w)

print('type(ret) = ',type(ret), ', ret_val = ', ret)
# Out:
# debug 1. initial input variable =  [3.]
# debug 2. initial grad =  [0.]
# ========================================
# debug 3. idx =  (0,) , x[idx] =  3.0
# debug 4. grad[idx] = 6.000000000012662
# debug 5. grad = [6.]
# ========================================
# type(ret) =  <class 'numpy.ndarray'> , ret_val =  [6.]

# %%
import numpy as np

def numerical_derivative(f,x):
    delta_x=1e-4
    grad=np.zeros_like(x)
    print('debug 1. initial input variable = ', x)
    print('debug 2. initial grad = ', grad)
    # 구분선 출력 코드
    for i in range (40):
        print('=', end='')
    print()

    it=np.nditer(x,flags=['multi_index'], op_flags=['readwrite'])

    while not it.finished:
        idx=it.multi_index
        print('debug 3. idx = ', idx, ', x[idx] = ', x[idx])

        tmp_val=x[idx]
        x[idx]=float(tmp_val)+delta_x
        fx1=f(x) #f(x+delta_x)

        x[idx]=float(tmp_val)-delta_x
        fx2=f(x) #f(x-delta_x)
        grad[idx]=(fx1-fx2)/(2*delta_x)
        print('debug 4. grad[idx] =', grad[idx])
        print('debug 5. grad =', grad)
        
        # 구분선 출력 코드
        for i in range (40):
            print('=', end='')
        print() 
        
        x[idx]=tmp_val
        it.iternext()
    
    
    return grad

# 입력 변수가 2개인 함수 f(x,y)=2*x+3*x*y+y**3
def func1(w):
    x,y=w
    
    return 2*x+3*x*y+y**3

# lambda 함수 정의
f=lambda w: func1(w)

w=np.array([1.0,2.0])

# x=1.0, y=2.0에서의 편미분 값
ret=numerical_derivative(f,w)

print('type(ret) = ',type(ret), ', ret_val = ', ret)
# Out:
# debug 1. initial input variable =  [1. 2.]
# debug 2. initial grad =  [0. 0.]
# ========================================
# debug 3. idx =  (0,) , x[idx] =  1.0
# debug 4. grad[idx] = 7.999999999990237
# debug 5. grad = [8. 0.]
# ========================================
# debug 3. idx =  (1,) , x[idx] =  2.0
# debug 4. grad[idx] = 15.000000010019221
# debug 5. grad = [ 8.         15.00000001]
# ========================================
# type(ret) =  <class 'numpy.ndarray'> , ret_val =  [ 8.         15.00000001]

# %%
import numpy as np

def numerical_derivative(f,x):
    delta_x=1e-4
    grad=np.zeros_like(x)
    print('debug 1. initial input variable = ', x)
    print('debug 2. initial grad = ', grad)
    # 구분선 출력 코드
    for i in range (40):
        print('=', end='')
    print()

    it=np.nditer(x,flags=['multi_index'], op_flags=['readwrite'])

    while not it.finished:
        idx=it.multi_index
        print('debug 3. idx = ', idx, ', x[idx] = ', x[idx])

        tmp_val=x[idx]
        x[idx]=float(tmp_val)+delta_x
        fx1=f(x) #f(x+delta_x)

        x[idx]=float(tmp_val)-delta_x
        fx2=f(x) #f(x-delta_x)
        grad[idx]=(fx1-fx2)/(2*delta_x)
        print('debug 4. grad[idx] =', grad[idx])
        print('debug 5. grad =', grad)
        # 구분선 출력 코드
        for i in range (40):
            print('=', end='')
        print() 
        
        x[idx]=tmp_val
        it.iternext()
    
    
    return grad

# 입력 변수가 4개이고 행렬 형태로 값이 주어지는 함수 f(w,x,y,z)=w*x+x*y*z+3*w+(y**2)*z
def func1(W):
    w=W[0,0]
    x=W[0,1]
    y=W[1,0]
    z=W[1,1]
    return w*x+x*y*z+3*w+(y**2)*z

# lambda 함수 정의
f=lambda w: func1(w)

w=np.array([[1.0,2.0],[3.0,4.0]])

# w=1.0, x=2.0, y=3.0, z=4.0에서의 편미분 값
ret=numerical_derivative(f,w)

print('type(ret) = ',type(ret), ', ret_val = ', ret)
# Out:
# debug 1. initial input variable =  [[1. 2.]
#  [3. 4.]]
# debug 2. initial grad =  [[0. 0.]
#  [0. 0.]]
# ========================================
# debug 3. idx =  (0, 0) , x[idx] =  1.0
# debug 4. grad[idx] = 5.000000000023874
# debug 5. grad = [[5. 0.]
#  [0. 0.]]
# ========================================
# debug 3. idx =  (0, 1) , x[idx] =  2.0
# debug 4. grad[idx] = 13.00000000000523
# debug 5. grad = [[ 5. 13.]
#  [ 0.  0.]]
# ========================================
# debug 3. idx =  (1, 0) , x[idx] =  3.0
# debug 4. grad[idx] = 32.00000000006753
# debug 5. grad = [[ 5. 13.]
#  [32.  0.]]
# ========================================
# debug 3. idx =  (1, 1) , x[idx] =  4.0
# debug 4. grad[idx] = 15.000000000000568
# debug 5. grad = [[ 5. 13.]
#  [32. 15.]]
# ========================================
# type(ret) =  <class 'numpy.ndarray'> , ret_val =  [[ 5. 13.]
#  [32. 15.]]
